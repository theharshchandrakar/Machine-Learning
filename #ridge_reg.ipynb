# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score 
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder

# %%
import os
os.chdir('G://My Drive/#myCDACfiles/MachineLearning/Datasets')

# %% [markdown]
# Hyper Parameter Tuning

# %%
alphas = [0.001, 0.01, 0.1, 1, 1.5, 2.5, 5, 10]
scores = []
for a in alphas:
    ridge = Ridge(alpha=a)
    ridge.fit(X_train, y_train)
    y_pred = ridge.predict(X_test)
    scores.append([a, mean_squared_error(y_test, y_pred)])
df_scores = pd.DataFrame(scores, columns=["alpha", "score"])
df_scores.sort_values("score")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       2 scores = []
#       3 for a in alphas:
# ----> 4     ridge = Ridge(alpha=a)
#       5     ridge.fit(X_train, y_train)
#       6     y_pred = ridge.predict(X_test)
#
# NameError: name 'Ridge' is not defined

# %%
housing = pd.read_csv('Housing.csv')
X = housing.drop('medv', axis=1)
y = housing['medv']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 housing = pd.read_csv('Housing.csv')
# ----> 2 X = housing.drop('medv', axis=1)
#       3 y = housing['medv']
#
# File c:\Users\dbda.STUDENTSDC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File c:\Users\dbda.STUDENTSDC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File c:\Users\dbda.STUDENTSDC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File c:\Users\dbda.STUDENTSDC\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['medv'] not found in axis"

# %%
ohe = OneHotEncoder(drop='first', sparse_output=False).set_output(transform='pandas')
col_trnf = ColumnTransformer([('OHE',ohe, list(housing.columns[housing.dtypes==object]))],
                             remainder = 'passthrough',
                             verbose_feature_names_out = False)
col_trnf = col_trnf.set_output(transform='pandas')
X = col_trnf.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ohe = OneHotEncoder(drop='first', sparse_output=False).set_output(transform='pandas')
#       2 col_trnf = ColumnTransformer([('OHE',ohe, list(housing.columns[housing.dtypes==object]))],
#       3                              remainder = 'passthrough',
#       4                              verbose_feature_names_out = False)
#       5 col_trnf = col_trnf.set_output(transform='pandas')
#
# NameError: name 'OneHotEncoder' is not defined

# %%
np.linspace(0.001, 15, 10)
# Out:
# array([1.00000000e-03, 1.66755556e+00, 3.33411111e+00, 5.00066667e+00,
#        6.66722222e+00, 8.33377778e+00, 1.00003333e+01, 1.16668889e+01,
#        1.33334444e+01, 1.50000000e+01])

# %% [markdown]
# Exp_Salaries

# %%
sals = pd.read_csv("Exp_Salaries.csv")
X, y = sals.drop('Salary', axis=1), sals['Salary']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=25)

# %%
aplhas = col.linspace(0.001, 15, 30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 aplhas = col.linspace(0.001, 15, 30)
#
# NameError: name 'col' is not defined

# %%
alphas = [0.001, 0.01, 0.1, 1, 1.5, 2.5, 5, 10]
scores = []
for a in alphas:
    ridge = Ridge(alpha=a)
    ridge.fit(X_train, y_train)
    y_pred = ridge.predict(X_test)
    scores.append([a, mean_squared_error(y_test, y_pred)])
df_scores = pd.DataFrame(scores, columns=["alpha", "score"])
df_scores.sort_values("score")
